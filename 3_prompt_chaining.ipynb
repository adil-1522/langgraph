# %%
from langgraph.graph import StateGraph,START,END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv
import os

# %%
load_dotenv()

GROQ_API_KEY = os.getenv("GROQ_API_KEY")

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key=GROQ_API_KEY
)

# %%
class BlogState(TypedDict):
    title:str
    outline:str
    content:str

# %%
def create_outline(state: BlogState)->BlogState:

    #fetch title
    title = state['title']

    #call llm gen oultine
    prompt = f'Generate an outline for a blog on the topic -{title}'
    outline = llm.invoke(prompt).content

    #update staticmethod
    state['outline'] = outline

    return state

# %%
def create_blog(state:BlogState)->BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title-{title} using the following outline -{outline}'

    content = llm.invoke(prompt).content

    state['content'] = content


    return state

# %%
graph = StateGraph(BlogState)

#nodes
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)


#edges
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow = graph.compile()

# %%
initial_state ={'title':'Rise of AI in India'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Here\'s a suggested outline for a blog on the "Rise of AI in India":\n\n**I. Introduction**\n  * Brief overview of Artificial Intelligence (AI) and its growing importance globally\n  * Context: India\'s increasing focus on technology and innovation\n  * Thesis statement: India is experiencing a significant rise in AI adoption, driven by government initiatives, industry investments, and a growing talent pool.\n\n**II. Government Initiatives and Policies**\n  * Overview of Indian government\'s AI-related initiatives (e.g., National AI Strategy, AI Task Force)\n  * Discussion of key policies and programs (e.g., Digital India, Make in India, Startup India)\n  * Examples of government-funded AI projects and research institutions\n\n**III. Industry Adoption and Investment**\n  * Overview of AI adoption in various Indian industries (e.g., IT, healthcare, finance, manufacturing)\n  * Discussion of key players and startups in the Indian AI ecosystem\n  * Examples of investments in AI research and development by Indian companies and foreign investors\n\n**IV. Talent Pool and Education**\n  * Discussion of India\'s growing pool of AI talent and the role of education in developing AI skills\n  * Overview of AI-related courses and programs offered by Indian universities and institutes\n  * Examples of initiatives to promote AI education and training (e.g., online courses, hackathons, competitions)\n\n**V. Applications and Use Cases**\n  * Examples of AI applications in various sectors, such as:\n    + Healthcare: disease diagnosis, personalized medicine\n    + Finance: credit scoring, fraud detection\n    + Manufacturing: predictive maintenance, quality control\n    + Transportation: autonomous vehicles, route optimization\n  * Discussion of the potential benefits and challenges of AI adoption in these sectors\n\n**VI. Challenges and Limitations**\n  * Discussion of the challenges facing AI adoption in India, such as:\n    + Data quality and availability\n    + Infrastructure and computational resources\n    + Regulatory frameworks and ethics\n    + Job displacement and skills gap\n  * Examples of initiatives to address these challenges\n\n**VII. Future Outlook and Opportunities**\n  * Discussion of the future prospects for AI in India, including potential areas of growth and innovation\n  * Examples of emerging trends and technologies (e.g., Edge AI, Explainable AI)\n  * Call to action: encouraging readers to explore AI opportunities and contribute to India\'s AI ecosystem\n\n**VIII. Conclusion**\n  * Recap of the rise of AI in India and its potential impact on the country\'s economy and society\n  * Final thoughts and recommendations for stakeholders (government, industry, academia, individuals) to promote AI adoption and development in India.\n\nThis outline provides a comprehensive framework for exploring the rise of AI in India, covering government initiatives, industry adoption, talent pool, applications, challenges, and future outlook. You can modify it to fit your specific needs and writing style.', 'content': "**The Rise of AI in India: A New Era of Innovation and Growth**\n\n**Introduction**\n\nArtificial Intelligence (AI) has been making waves globally, transforming industries and revolutionizing the way we live and work. As a country with a strong focus on technology and innovation, India is poised to become a significant player in the AI landscape. With its vast talent pool, growing startup ecosystem, and increasing investments in research and development, India is experiencing a significant rise in AI adoption. In this blog, we will explore the current state of AI in India, its applications, challenges, and future prospects, and discuss the role of government initiatives, industry investments, and education in driving this growth.\n\n**Government Initiatives and Policies**\n\nThe Indian government has been actively promoting AI adoption through various initiatives and policies. The ...

# %%
print(final_state['outline'])
# Out:
# Here's a suggested outline for a blog on the "Rise of AI in India":
#
# **I. Introduction**
#   * Brief overview of Artificial Intelligence (AI) and its growing importance globally
#   * Context: India's increasing focus on technology and innovation
#   * Thesis statement: India is experiencing a significant rise in AI adoption, driven by government initiatives, industry investments, and a growing talent pool.
#
# **II. Government Initiatives and Policies**
#   * Overview of Indian government's AI-related initiatives (e.g., National AI Strategy, AI Task Force)
#   * Discussion of key policies and programs (e.g., Digital India, Make in India, Startup India)
#   * Examples of government-funded AI projects and research institutions
#
# **III. Industry Adoption and Investment**
#   * Overview of AI adoption in various Indian industries (e.g., IT, healthcare, finance, manufacturing)
#   * Discussion of key players and startups in the Indian AI ecosystem
#   * Examples of investments in AI research and development by Indian companies and foreign investors
#
# **IV. Talent Pool and Education**
#   * Discussion of India's growing pool of AI talent and the role of education in developing AI skills
#   * Overview of AI-related courses and programs offered by Indian universities and institutes
#   * Examples of initiatives to promote AI education and training (e.g., online courses, hackathons, competitions)
#
# **V. Applications and Use Cases**
#   * Examples of AI applications in various sectors, such as:
#     + Healthcare: disease diagnosis, personalized medicine
#     + Finance: credit scoring, fraud detection
#     + Manufacturing: predictive maintenance, quality control
#     + Transportation: autonomous vehicles, route optimization
#   * Discussion of the potential benefits and challenges of AI adoption in these sectors
#
# **VI. Challenges and Limitations**
#   * Discussion of the challenges facing AI adoption in India, such as:
#     + Data quality and availability
#     + Infrastructure and computational resources
#     + Regulatory frameworks and ethics
#     + Job displacement and skills gap
#   * Examples of initiatives to address these challenges
#
# **VII. Future Outlook and Opportunities**
#   * Discussion of the future prospects for AI in India, including potential areas of growth and innovation
#   * Examples of emerging trends and technologies (e.g., Edge AI, Explainable AI)
#   * Call to action: encouraging readers to explore AI opportunities and contribute to India's AI ecosystem
#
# **VIII. Conclusion**
#   * Recap of the rise of AI in India and its potential impact on the country's economy and society
#   * Final thoughts and recommendations for stakeholders (government, industry, academia, individuals) to promote AI adoption and development in India.
#
# This outline provides a comprehensive framework for exploring the rise of AI in India, covering government initiatives, industry adoption, talent pool, applications, challenges, and future outlook. You can modify it to fit your specific needs and writing style.

# %%
print(final_state['content'])
# Out:
# **The Rise of AI in India: A New Era of Innovation and Growth**
#
# **Introduction**
#
# Artificial Intelligence (AI) has been making waves globally, transforming industries and revolutionizing the way we live and work. As a country with a strong focus on technology and innovation, India is poised to become a significant player in the AI landscape. With its vast talent pool, growing startup ecosystem, and increasing investments in research and development, India is experiencing a significant rise in AI adoption. In this blog, we will explore the current state of AI in India, its applications, challenges, and future prospects, and discuss the role of government initiatives, industry investments, and education in driving this growth.
#
# **Government Initiatives and Policies**
#
# The Indian government has been actively promoting AI adoption through various initiatives and policies. The National AI Strategy, launched in 2018, aims to make India a leader in AI research and development, and to leverage AI for social and economic benefits. The AI Task Force, set up by the government, has been working to identify areas where AI can be applied to improve governance and public services. Other key policies, such as Digital India, Make in India, and Startup India, have also been instrumental in promoting AI adoption and innovation.
#
# The government has also established several research institutions and funded projects to promote AI research and development. For example, the Indian Institute of Technology (IIT) has set up AI research centers, and the Department of Science and Technology has launched the AI Mission, which aims to promote AI research and development in the country. These initiatives have created a favorable environment for AI adoption and innovation in India.
#
# **Industry Adoption and Investment**
#
# Indian industries, such as IT, healthcare, finance, and manufacturing, are increasingly adopting AI to improve efficiency, reduce costs, and enhance customer experience. Many Indian companies, such as Tata, Infosys, and Wipro, have established AI research and development centers, and are investing heavily in AI research and development. Foreign investors, such as Google, Microsoft, and Amazon, are also investing in Indian AI startups and research institutions.
#
# The Indian AI ecosystem is also witnessing the emergence of new startups, such as Niki.ai, which offers AI-powered chatbots for customer service, and Locus.sh, which provides AI-powered logistics and supply chain management solutions. These startups are not only creating innovative AI solutions but also generating employment opportunities and driving economic growth.
#
# **Talent Pool and Education**
#
# India has a vast pool of talented engineers and researchers, which is a significant advantage for AI adoption. The country's education system is also evolving to meet the growing demand for AI skills. Many Indian universities and institutes, such as IIT, Indian Institute of Science (IISc), and National Institute of Technology (NIT), offer AI-related courses and programs. Online platforms, such as Coursera and edX, are also offering AI courses and certifications, making it easier for people to acquire AI skills.
#
# Initiatives, such as hackathons, competitions, and coding challenges, are also being organized to promote AI education and training. For example, the Indian government's AI for All initiative aims to promote AI education and training among school students, and the NASSCOM AI Game Jam is a coding challenge that encourages developers to build AI-powered games.
#
# **Applications and Use Cases**
#
# AI has a wide range of applications in various sectors, including healthcare, finance, manufacturing, and transportation. In healthcare, AI is being used for disease diagnosis, personalized medicine, and patient care. For example, AI-powered chatbots are being used to provide medical consultations, and AI-powered algorithms are being used to analyze medical images and diagnose diseases.
#
# In finance, AI is being used for credit scoring, fraud detection, and risk management. For example, AI-powered systems are being used to detect fraudulent transactions, and AI-powered algorithms are being used to predict credit risk and provide personalized investment advice.
#
# In manufacturing, AI is being used for predictive maintenance, quality control, and supply chain management. For example, AI-powered sensors are being used to predict equipment failures, and AI-powered algorithms are being used to optimize production processes and reduce waste.
#
# In transportation, AI is being used for autonomous vehicles, route optimization, and traffic management. For example, AI-powered systems are being used to develop autonomous vehicles, and AI-powered algorithms are being used to optimize traffic flow and reduce congestion.
#
# **Challenges and Limitations**
#
# Despite the growing adoption of AI in India, there are several challenges and limitations that need to be addressed. One of the major challenges is the lack of quality data, which is essential for training AI models. The country also lacks infrastructure and computational resources, which are necessary for developing and deploying AI solutions.
#
# Regulatory frameworks and ethics are also a major concern, as AI raises several ethical questions, such as bias, privacy, and job displacement. The government and industry need to work together to develop regulatory frameworks that promote AI adoption while addressing these concerns.
#
# Job displacement and skills gap are also significant challenges, as AI automation may displace certain jobs, while creating new ones. The government and industry need to work together to develop training programs that help workers acquire new skills and adapt to the changing job market.
#
# **Future Outlook and Opportunities**
#
# Despite the challenges and limitations, the future of AI in India looks promising. The country is expected to become a significant player in the global AI market, with the market size expected to reach $7.8 billion by 2025. Emerging trends and technologies, such as Edge AI, Explainable AI, and Transfer Learning, are expected to create new opportunities for innovation and growth.
#
# The Indian government and industry need to work together to promote AI adoption and development, and to address the challenges and limitations. The country needs to invest in AI research and development, and to develop a skilled workforce that can develop and deploy AI solutions.
#
# **Conclusion**
#
# The rise of AI in India is a significant trend that is transforming the country's economy and society. With its vast talent pool, growing startup ecosystem, and increasing investments in research and development, India is poised to become a significant player in the global AI market. However, the country needs to address the challenges and limitations, such as data quality, infrastructure, regulatory frameworks, and job displacement, to promote AI adoption and development.
#
# The government, industry, and academia need to work together to develop a comprehensive strategy for AI adoption and development, and to invest in AI research and development. Individuals also need to acquire AI skills and adapt to the changing job market. By working together, India can harness the power of AI to drive innovation, growth, and prosperity, and to become a leader in the global AI landscape.
